# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt

# Import necessary modules from dicomviewer
sys.path.append('/homebase/DL_projects/code_sync/myMedIADIRLab/third_party/dicomviewer/src')
from dicom_viewer.readers.RTStructReader import RTStructReader
from dicom_viewer.readers.DICOMImageReader import DICOMImageReader

# %%
### no gad
image_path_1 = "/database/brainmets/dicom/Data/SRS0871/1999-04__Studies/SRS0871_SRS0871_MR_1999-04-02_000000_._axial1_n47__00000"
### with gad
image_path_2 = "/database/brainmets/dicom/Data/SRS0871/1999-04__Studies/SRS0871_SRS0871_MR_1999-04-02_071849_MR.BR_T1.AX_n47__00000"


image_reader_1 = DICOMImageReader(image_path_1, modality="MR")
image_reader_1.read()
image_reader_2 = DICOMImageReader(image_path_2, modality="MR")
image_reader_2.read()
# Out:
# <SimpleITK.SimpleITK.Image; proxy of <Swig Object of type 'itk::simple::Image *' at 0x7f5c64e3fc30> >

# %%
print(image_reader_1.image)
# Out:
# Image (0x103494f0)
#   RTTI typeinfo:   itk::Image<unsigned short, 3u>
#   Reference Count: 1
#   Modified Time: 3470
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (none)
#   Source output name: (none)
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 1800
#   UpdateMTime: 3466
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [256, 256, 47]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [256, 256, 47]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [256, 256, 47]
#   Spacing: [1.17432, 1.17432, 2.98748]
#   Origin: [0, 0, -137.424]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 1.17432 0 0
# 0 1.17432 0
# 0 0 2.98748
#
#   PointToIndexMatrix:
# 0.851559 0 0
# 0 0.851559 0
# 0 0 0.33473
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
# ...

# %%
print(image_reader_2.image)
# Out:
# Image (0xfbb5c50)
#   RTTI typeinfo:   itk::Image<short, 3u>
#   Reference Count: 1
#   Modified Time: 5324
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (none)
#   Source output name: (none)
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 3653
#   UpdateMTime: 5320
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [256, 256, 47]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [256, 256, 47]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [256, 256, 47]
#   Spacing: [1.17188, 1.17188, 3]
#   Origin: [-150, -150, -62]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 1.17188 0 0
# 0 1.17188 0
# 0 0 3
#
#   PointToIndexMatrix:
# 0.853333 0 0
# 0 0.853333 0
# 0 0 0.333333
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (0x103a5490)
# ...
